# %%
# !git clone https://oauth2:<TOKEN>@github.com/tharindu326/TennisH.git
# Out:
# Cloning into 'TennisH'...
# remote: Enumerating objects: 153, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 153 (delta 14), reused 28 (delta 9), pack-reused 119 (from 1)
# Receiving objects: 100% (153/153), 82.79 MiB | 33.95 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
# %cd TennisH/
# Out:
# /content/TennisH

# %%
# !pip3 install easydict moviepy paddlepaddle==2.6.2 paddleocr==2.9.1 lap cython_bbox
# OR
#!pip3 install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.7/544.7 kB 41.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.9/161.9 kB 16.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 83.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 111.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 60.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 62.1 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.144 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.1/112.6 GB disk)

# %%
# !gdown https://drive.google.com/uc?id=1bKxvgqE8AVhaVojMKEzNre9PsqG_sPL6
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1bKxvgqE8AVhaVojMKEzNre9PsqG_sPL6
# From (redirected): https://drive.google.com/uc?id=1bKxvgqE8AVhaVojMKEzNre9PsqG_sPL6&confirm=t&uuid=5712d6c7-1a38-4dac-bc2f-32d2155a7107
# To: /content/TennisH/test2_WuxiOpenCourt_test1.mp4
# 100% 303M/303M [00:03<00:00, 80.8MB/s]

# %%
# !gdown https://drive.google.com/uc?id=11l_7cJnUH_YT7iX8Jp3U5vWyqwN0oMos
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=11l_7cJnUH_YT7iX8Jp3U5vWyqwN0oMos
# From (redirected): https://drive.google.com/uc?id=11l_7cJnUH_YT7iX8Jp3U5vWyqwN0oMos&confirm=t&uuid=1017711b-6175-4a68-ba14-b687f25859ca
# To: /content/TennisH/test3.mp4
# 100% 107M/107M [00:00<00:00, 143MB/s]

# %%
# !python main.py -s test2_WuxiOpenCourt_test1.mp4
# Out:
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ...

# %%
# !zip test2_WuxiOpenCourt_test1_20250525_192115.zip -r /content/TennisH/outputs/test2_WuxiOpenCourt_test1_20250525_192115
# Out:
# updating: content/TennisH/outputs/test2_WuxiOpenCourt_test1_20250525_192115/ (stored 0%)
#   adding: content/TennisH/outputs/test2_WuxiOpenCourt_test1_20250525_192115/advantage_break_point_extended_rally_0-1_50-40_666-733.mp4 (deflated 2%)
#   adding: content/TennisH/outputs/test2_WuxiOpenCourt_test1_20250525_192115/combined_highlights.mp4 (deflated 0%)
#   adding: content/TennisH/outputs/test2_WuxiOpenCourt_test1_20250525_192115/break_point_extended_rally_0-1_40-30_326-391.mp4 (deflated 2%)
#   adding: content/TennisH/outputs/test2_WuxiOpenCourt_test1_20250525_192115/break_point_extended_rally_0-0_30-40_82-114.mp4 (deflated 2%)
#   adding: content/TennisH/outputs/test2_WuxiOpenCourt_test1_20250525_192115/test2_WuxiOpenCourt_test1_20250525_192115.csv (deflated 62%)
#   adding: content/TennisH/outputs/test2_WuxiOpenCourt_test1_20250525_192115/extended_rally_0-0_30-15_34-64.mp4 (deflated 2%)
# ...

# %%
# !python main.py -s test3.mp4
# Out:
# start processing video test3.mp4
# video_fps: 25
# Processing test3: 100% 6802/6802 [37:52<00:00,  2.99it/s]

# %%
from google.colab import files
file_path = '/content/TennisH/outputs/processed_test2_WuxiOpenCourt_test1.mp4'
files.download(file_path)

# %%
file_path = '/content/TennisH/outputs/processed_test3.mp4'
files.download(file_path)
